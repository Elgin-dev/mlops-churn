# %% [markdown]
# ## 1. Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/processed/cleaned_data.csv")

print("Shape:", df.shape)
df.head()
# Out:
# Shape: (1000, 8)
#   customer_id   age  tenure_months  monthly_charges  support_calls  \
# 0       C0001  56.0             35           103.62              2
# 1       C0002  69.0             51           104.89              0
# 2       C0003  46.0             15            75.67              3
# 3       C0004  32.0             25            30.57              1
# 4       C0005  60.0             55            55.83              1
#
#   contract_type  usage_hours  churn
# 0       Monthly         19.6      1
# 1        Yearly         17.5      1
# 2       Monthly        119.1      1
# 3       Monthly         84.7      0
# 4       Monthly         15.4      0

# %%
df.isnull().sum()
# Out:
# customer_id        0
# age                0
# tenure_months      0
# monthly_charges    0
# support_calls      0
# contract_type      0
# usage_hours        0
# churn              0
# dtype: int64

# %%
plt.figure(figsize=(6, 4))

sns.countplot(data=df, x="churn")

plt.title("Customer Churn Distribution")
plt.xlabel("Churn (0 = Stay, 1 = Churn)")
plt.ylabel("Number of Customers")

plt.show()
print(df["churn"].value_counts(normalize=True) * 100)
# Out:
# churn
# 1    51.7
# 0    48.3
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7, 4))

sns.countplot(data=df, x="contract_type")

plt.title("Contract Type Distribution")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.countplot(
    data=df,
    x="contract_type",
    hue="churn"
)

plt.title("Contract Type vs Churn")
plt.xlabel("Contract Type")
plt.ylabel("Number of Customers")

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.histplot(
    data=df,
    x="age",
    bins=20,
    kde=True
)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# %%
numeric_cols = [
    "age",
    "tenure_months",
    "monthly_charges",
    "support_calls",
    "usage_hours",
    "churn"
]

plt.figure(figsize=(8, 6))

correlation = df[numeric_cols].corr()

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f",
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(7, 4))

sns.boxplot(
    data=df,
    x="churn",
    y="usage_hours"
)

plt.title("Usage Hours vs Churn")
plt.xlabel("Churn (0 = Stay, 1 = Churn)")
plt.ylabel("Usage Hours")

plt.show()
